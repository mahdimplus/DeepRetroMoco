# %%
import nbimporter
from functions import *
# %matplotlib inline

# %%
D7_dir='/home/mahdi/Desktop/data_selection_D7'
n,name=count(D7_dir)
out_dir='/home/mahdi/Desktop/valid'
n1,name1=count(out_dir)

# %%
i=0
reference=0
maximum_intensity=1705
loadable_model='200epoch_with_val.h5'
slice_num=5

# %% [markdown]
# # plot for specific slice

# %%
input_direction='/home/mahdi/Desktop/valid/'+name1[i][0]+'/'+'sct_seg/fmri_rmvol_moco.nii.gz'
title='sct_data'
flow_one_slice(input_direction,reference,maximum_intensity,loadable_model,slice_num,'',title)

input_direction='/home/mahdi/Desktop/valid/'+name1[i][0]+'/'+'main_seg'+'/'+name[i][0]
title='main_data'
flow_one_slice(input_direction,reference,maximum_intensity,loadable_model,slice_num,'',title)

x=(len(name[i][0][:])-7)
input_direction='/home/mahdi/Desktop/centerline/'+name1[i][0]+'/output/zero_ref/'+name[i][0][:x]+'_cplus.'+name[i][0][-6:]

title='my_data'
flow_one_slice(input_direction,reference,maximum_intensity,loadable_model,slice_num,'',title)

# %%
x=(len(name[i][0][:])-7)
input_direction='/home/mahdi/Desktop/centerline/'+name1[i][0]+'/output/zero_ref/'+name[i][0][:x]+'_cplus.'+name[i][0][-6:]

title='my_data'
flow_one_slice(input_direction,reference,maximum_intensity,loadable_model,slice_num,'',title)

# %% [markdown]
# # plot all slice

# %%
i=50
input_direction='/home/mahdi/Desktop/valid/'+name1[i][0]+'/'+'sct_seg/fmri_rmvol_moco.nii.gz'
title='sct_data'
flow_all_slice(input_direction,reference,maximum_intensity,loadable_model,'',title)


input_direction='/home/mahdi/Desktop/valid/'+name1[i][0]+'/'+'main_seg'+'/'+name[i][0]
title='main_data'
flow_all_slice(input_direction,reference,maximum_intensity,loadable_model,'',title)

x=(len(name[i][0][:])-7)
input_direction='/home/mahdi/Desktop/centerline/'+name1[i][0]+'/output/zero_ref/'+name[i][0][:x]+'_cplus.'+name[i][0][-6:]

title='my_data'
flow_all_slice(input_direction,reference,maximum_intensity,loadable_model,'',title)

# %%
i=25
input_direction='/home/mahdi/Desktop/valid/'+name1[i][0]+'/'+'sct_seg/fmri_rmvol_moco.nii.gz'
title='sct_data'
flow_all_slice(input_direction,reference,maximum_intensity,loadable_model,'',title)
plt.savefig('foo.png')

input_direction='/home/mahdi/Desktop/valid/'+name1[i][0]+'/'+'main_seg'+'/'+name[i][0]
title='main_data'
flow_all_slice(input_direction,reference,maximum_intensity,loadable_model,'',title)

x=(len(name[i][0][:])-7)
input_direction='/home/mahdi/Desktop/centerline/'+name1[i][0]+'/output/zero_ref/'+name[i][0][:x]+'_c.'+name[i][0][-6:]

title='my_data'
flow_all_slice(input_direction,reference,maximum_intensity,loadable_model,'',title)

# %%
i=12
input_direction='/home/mahdi/Desktop/valid/'+name1[i][0]+'/'+'sct_seg/fmri_rmvol_moco.nii.gz'
title='sct_data'
flow_all_slice(input_direction,reference,maximum_intensity,loadable_model,'',title)
plt.savefig('foo.png')

input_direction='/home/mahdi/Desktop/valid/'+name1[i][0]+'/'+'main_seg'+'/'+name[i][0]
title='main_data'
flow_all_slice(input_direction,reference,maximum_intensity,loadable_model,'',title)

x=(len(name[i][0][:])-7)
input_direction='/home/mahdi/Desktop/centerline/'+name1[i][0]+'/output/zero_ref/'+name[i][0][:x]+'_cplus.'+name[i][0][-6:]

title='my_data'
flow_all_slice(input_direction,reference,maximum_intensity,loadable_model,'',title)

# %%
i=40
input_direction='/home/mahdi/Desktop/valid/'+name1[i][0]+'/'+'sct_seg/fmri_rmvol_moco.nii.gz'
title='sct_data'
flow_all_slice(input_direction,reference,maximum_intensity,loadable_model,'',title)
plt.savefig('foo.png')

input_direction='/home/mahdi/Desktop/valid/'+name1[i][0]+'/'+'main_seg'+'/'+name[i][0]
title='main_data'
flow_all_slice(input_direction,reference,maximum_intensity,loadable_model,'',title)

x=(len(name[i][0][:])-7)
input_direction='/home/mahdi/Desktop/centerline/'+name1[i][0]+'/output/zero_ref/'+name[i][0][:x]+'_cplus.'+name[i][0][-6:]

title='my_data'
flow_all_slice(input_direction,reference,maximum_intensity,loadable_model,'',title)

# %% [markdown]
# # Compare two charts

# %%
i=50
x=(len(name[i][0][:])-7)
input_direction0='/home/mahdi/Desktop/centerline/'+name1[i][0]+'/output/zero_ref/'+name[i][0][:x]+'_c.'+name[i][0][-6:]

input_direction1='/home/mahdi/Desktop/valid/'+name1[i][0]+'/'+'main_seg'+'/'+name[i][0]

title='m'
l1="main_movement"
l2="centerline_fix_movement"

flow_between_two(input_direction0,input_direction1,reference,
                 maximum_intensity,loadable_model,'',
                 title,l1,l2)

# %%
i=50
x=(len(name[i][0][:])-7)
input_direction0='/home/mahdi/Desktop/centerline/'+name1[i][0]+'/output/zero_ref/'+name[i][0][:x]+'_c.'+name[i][0][-6:]

input_direction1='/home/mahdi/Desktop/valid/'+name1[i][0]+'/'+'sct_seg/fmri_rmvol_moco.nii.gz'

title='m'
l1="centerline_fix_movement"
l2="sct_movement"

flow_between_two(input_direction0,input_direction1,reference,
                 maximum_intensity,loadable_model,'',
                 title,l1,l2)

# %%
i=50
x=(len(name[i][0][:])-7)
input_direction0='/home/mahdi/Desktop/centerline/'+name1[i][0]+'/output/zero_ref/'+name[i][0][:x]+'_cplus.'+name[i][0][-6:]

input_direction1='/home/mahdi/Desktop/valid/'+name1[i][0]+'/'+'sct_seg/fmri_rmvol_moco.nii.gz'
reference=0

title='m'
l1="myalgo_movement"
l2="sct_movement"

flow_between_two(input_direction0,input_direction1,reference,
                 maximum_intensity,loadable_model,' ',
                 title,l1,l2)

# %%
i=50
x=(len(name[i][0][:])-7)

input_direction0='/home/mahdi/Desktop/valid/'+name1[i][0]+'/my_seg/zero_ref/'+name[i][0][:x]+'_plus.'+name[i][0][-6:]

input_direction1='/home/mahdi/Desktop/valid/'+name1[i][0]+'/'+'sct_seg/fmri_rmvol_moco.nii.gz'
reference=-1

title='movement compare by mid reference'
l1="DeepRetroMoco_movement"
l2="sct_movement"

flow_between_two(input_direction0,input_direction1,reference,
                 maximum_intensity,loadable_model,'',
                 title,l1,l2)

# %%
i=12
x=(len(name[i][0][:])-7)

input_direction0='/home/mahdi/Desktop/valid/'+name1[i][0]+'/my_seg/zero_ref/'+name[i][0][:x]+'_plus.'+name[i][0][-6:]

input_direction1='/home/mahdi/Desktop/valid/'+name1[i][0]+'/'+'sct_seg/fmri_rmvol_moco.nii.gz'
reference=-1

title='m'
l1="myalgo_movement"
l2="sct_movement"

flow_between_two(input_direction0,input_direction1,reference,
                 maximum_intensity,loadable_model,'',
                 title,l1,l2)

# %%
i=12
x=(len(name[i][0][:])-7)

input_direction0='/home/mahdi/Desktop/valid/'+name1[i][0]+'/my_seg/zero_ref/'+name[i][0][:x]+'_plus.'+name[i][0][-6:]

input_direction1='/home/mahdi/Desktop/valid/'+name1[i][0]+'/'+'sct_seg/fmri_rmvol_moco.nii.gz'
reference=0

title='movement compare by first reference'
l1="myalgo_movement"
l2="sct_movement"

flow_between_two(input_direction0,input_direction1,reference,
                 maximum_intensity,loadable_model,'',
                 title,l1,l2)

# %%
i=25
x=(len(name[i][0][:])-7)

input_direction0='/home/mahdi/Desktop/valid/'+name1[i][0]+'/my_seg/zero_ref/'+name[i][0][:x]+'_plus.'+name[i][0][-6:]

input_direction1='/home/mahdi/Desktop/valid/'+name1[i][0]+'/'+'sct_seg/fmri_rmvol_moco.nii.gz'
reference=0

title='movement compare by first reference'
l1="myalgo_movement"
l2="sct_movement"

flow_between_two(input_direction0,input_direction1,reference,
                 maximum_intensity,loadable_model,'',
                 title,l1,l2)

# %%
i=75
x=(len(name[i][0][:])-7)

input_direction0='/home/mahdi/Desktop/valid/'+name1[i][0]+'/my_seg/zero_ref/'+name[i][0][:x]+'_plus.'+name[i][0][-6:]

input_direction1='/home/mahdi/Desktop/valid/'+name1[i][0]+'/'+'sct_seg/fmri_rmvol_moco.nii.gz'
reference=-1

title='movement compare by first reference'
l1="myalgo_movement"
l2="sct_movement"

flow_between_two(input_direction0,input_direction1,reference,
                 maximum_intensity,loadable_model,'',
                 title,l1,l2)

# %%
i=50
reference=-1
maximum_intensity=1705
loadable_model='200epoch_with_val.h5'
slice_num=5
x=(len(name[i][0][:])-7)
input_direction='/home/mahdi/Desktop/centerline/'+name1[i][0]+'/output/zero_ref/'+name[i][0][:x]+'_cplus.'+name[i][0][-6:]
title='my_data'



img_data,img=load_with_head(input_direction)
slice_number = img_data.shape[2]
header=img.header
img_mask_affine = img.affine
    # configure unet input shape (concatenation of moving and fixed images)
ndim = 2
unet_input_features = 2
# data shape 64*64
s=(64,64)
inshape = (*s, unet_input_features)
# configure unet features 
nb_features =[
    [64, 64, 64, 64],         # encoder features
    [64, 64, 64, 64, 64, 32,16]  # decoder features
             ]
# build model using VxmDense
inshape =s
vxm_model = vxm.networks.VxmDense(inshape, nb_features, int_steps=0)
# voxelmorph has a variety of custom loss classes
losses = [vxm.losses.MSE().loss, vxm.losses.Grad('l2').loss]
# usually, we have to balance the two losses by a hyper-parameter
lambda_param = 0.05
loss_weights = [1, lambda_param]
vxm_model.compile(optimizer='Adam', loss=losses, loss_weights=loss_weights, metrics=['accuracy'])
vxm_model.load_weights(loadable_model)

if reference>0:
    reference=str(reference)
if reference==0:
    reference='0'
if reference==-1:
    y=int(img_data.shape[3]/2)
    reference=str(y)
if reference==-2:
    reference=mean_directory



x_all_slice=[]
y_all_slice=[]

# %%
reference

# %%
x_all_slice=[]
y_all_slice=[]

# %%
for i in range(slice_number):
    prepare_data=ref(input_direction,maximum_intensity,i,reference)
    val_input, _ = prepare_data
    val_pred = vxm_model.predict(val_input)
    #val_pred=flow(input_direction,reference,maximum_intensity,loadable_model,slice_num)
    x=[]
    y=[]

    for i in range(val_pred[1][:,0,0,0].shape[0]):
        x.append(np.mean(val_pred[1][i,...,0]))
        y.append(np.mean(val_pred[1][i,...,1]))

    x_all_slice.append(x)
    y_all_slice.append(y)

# %%
x_all_slice=np.array(x_all_slice)
y_all_slice=np.array(y_all_slice)

# %%
mx=x_all_slice.mean(axis=0)
my=y_all_slice.mean(axis=0)

# %%
mx[int(reference)]=0
my[int(reference)]=0

# %%
h=(mx+my)/2
h[141]
